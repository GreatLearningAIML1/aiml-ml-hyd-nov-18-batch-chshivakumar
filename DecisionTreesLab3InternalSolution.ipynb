# %% [markdown]
# # Information about the dataset
#
# Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. They describe characteristics of the cell nuclei present in the image.
#
# Attribute Information
# 1. ID - ID number of the image
# 2. Clump Thickness - 1 to 10
# 3. Cell Size - 1 to 10
# 4. Cell Shape - 1 to 10
# 5. Marginal Adhesion - 1 to 10
# 6. Single Epethelial cell size - 1 to 10
# 7. Bare nuclei - 1 to 10
# 8. Normal Nucleoli - 1 to 10
# 9. Bland Chromatin - 1 to 10
# 10. Mitosis - 1 to 10
#
# Class - Dependent Variable - 2 for benign 4 for malignant

# %% [markdown]
# ### Read the data given in bc2.csv file

# %%
import pandas as pd
bc=pd.read_csv('bc2.csv')
bc.head()
# Out:
#         ID  ClumpThickness  Cell Size  Cell Shape  Marginal Adhesion  \
# 0  1000025               5          1           1                  1
# 1  1002945               5          4           4                  5
# 2  1015425               3          1           1                  1
# 3  1016277               6          8           8                  1
# 4  1017023               4          1           1                  3
#
#    Single Epithelial Cell Size Bare Nuclei  Normal Nucleoli  Bland Chromatin  \
# 0                            2           1                3                1
# 1                            7          10                3                2
# 2                            2           2                3                1
# 3                            3           4                3                7
# 4                            2           1                3                1
#
#    Mitoses  Class
# 0        1      2
# 1        1      2
# 2        1      2
# 3        1      2
# 4        1      2

# %% [markdown]
# ### Observe the no.of records in dataset and type of each feature

# %%
bc.dtypes
# Out:
# ID                              int64
# ClumpThickness                  int64
# Cell Size                       int64
# Cell Shape                      int64
# Marginal Adhesion               int64
# Single Epithelial Cell Size     int64
# Bare Nuclei                    object
# Normal Nucleoli                 int64
# Bland Chromatin                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %%
bc.shape
# Out:
# (699, 11)

# %% [markdown]
# ### Use summary statistics to check if missing values, outlier and encoding treament is necessary

# %%
bc.describe()
# Out:
#                  ID  ClumpThickness   Cell Size  Cell Shape  \
# count  6.990000e+02      699.000000  699.000000  699.000000
# mean   1.071704e+06        4.417740    3.134478    3.207439
# std    6.170957e+05        2.815741    3.051459    2.971913
# min    6.163400e+04        1.000000    1.000000    1.000000
# 25%    8.706885e+05        2.000000    1.000000    1.000000
# 50%    1.171710e+06        4.000000    1.000000    1.000000
# 75%    1.238298e+06        6.000000    5.000000    5.000000
# max    1.345435e+07       10.000000   10.000000   10.000000
#
#        Marginal Adhesion  Single Epithelial Cell Size  Normal Nucleoli  \
# count         699.000000                   699.000000       699.000000
# mean            2.806867                     3.216023         3.437768
# std             2.855379                     2.214300         2.438364
# min             1.000000                     1.000000         1.000000
# 25%             1.000000                     2.000000         2.000000
# 50%             1.000000                     2.000000         3.000000
# 75%             4.000000                     4.000000         5.000000
# max            10.000000                    10.000000        10.000000
#
#        Bland Chromatin     Mitoses       Class
# count       699.000000  699.000000  699.000000
# mean          2.866953    1.589413    2.689557
# std           3.053634    1.715078    0.951273
# min           1.000000    1.000000    2.000000
# 25%           1.000000    1.000000    2.000000
# 50%           1.000000    1.000000    2.000000
# 75%           4.000000    1.000000    4.000000
# max          10.000000   10.000000    4.000000

# %%
bc.describe().T
# Out:
#                              count          mean            std      min  \
# ID                           699.0  1.071704e+06  617095.729819  61634.0
# ClumpThickness               699.0  4.417740e+00       2.815741      1.0
# Cell Size                    699.0  3.134478e+00       3.051459      1.0
# Cell Shape                   699.0  3.207439e+00       2.971913      1.0
# Marginal Adhesion            699.0  2.806867e+00       2.855379      1.0
# Single Epithelial Cell Size  699.0  3.216023e+00       2.214300      1.0
# Normal Nucleoli              699.0  3.437768e+00       2.438364      1.0
# Bland Chromatin              699.0  2.866953e+00       3.053634      1.0
# Mitoses                      699.0  1.589413e+00       1.715078      1.0
# Class                        699.0  2.689557e+00       0.951273      2.0
#
#                                   25%        50%        75%         max
# ID                           870688.5  1171710.0  1238298.0  13454352.0
# ClumpThickness                    2.0        4.0        6.0        10.0
# Cell Size                         1.0        1.0        5.0        10.0
# Cell Shape                        1.0        1.0        5.0        10.0
# Marginal Adhesion                 1.0        1.0        4.0        10.0
# Single Epithelial Cell Size       2.0        2.0        4.0        10.0
# Normal Nucleoli                   2.0        3.0        5.0        10.0
# Bland Chromatin                   1.0        1.0        4.0        10.0
# Mitoses                           1.0        1.0        1.0        10.0
# Class                             2.0        2.0        4.0         4.0

# %%
bc.describe(include='all').T
# Out:
#                             count unique  top freq        mean       std  \
# ID                            699    NaN  NaN  NaN  1.0717e+06    617096
# ClumpThickness                699    NaN  NaN  NaN     4.41774   2.81574
# Cell Size                     699    NaN  NaN  NaN     3.13448   3.05146
# Cell Shape                    699    NaN  NaN  NaN     3.20744   2.97191
# Marginal Adhesion             699    NaN  NaN  NaN     2.80687   2.85538
# Single Epithelial Cell Size   699    NaN  NaN  NaN     3.21602    2.2143
# Bare Nuclei                   699     11    1  402         NaN       NaN
# Normal Nucleoli               699    NaN  NaN  NaN     3.43777   2.43836
# Bland Chromatin               699    NaN  NaN  NaN     2.86695   3.05363
# Mitoses                       699    NaN  NaN  NaN     1.58941   1.71508
# Class                         699    NaN  NaN  NaN     2.68956  0.951273
#
#                                min     25%          50%         75%  \
# ID                           61634  870688  1.17171e+06  1.2383e+06
# ClumpThickness                   1       2            4           6
# Cell Size                        1       1            1           5
# Cell Shape                       1       1            1           5
# Marginal Adhesion                1       1            1           4
# Single Epithelial Cell Size      1       2            2           4
# Bare Nuclei                    NaN     NaN          NaN         NaN
# Normal Nucleoli                  1       2            3           5
# Bland Chromatin                  1       1            1           4
# Mitoses                          1       1            1           1
# Class                            2       2            2           4
#
#                                      max
# ID                           1.34544e+07
# ClumpThickness                        10
# Cell Size                             10
# Cell Shape                            10
# Marginal Adhesion                     10
# Single Epithelial Cell Size           10
# Bare Nuclei                          NaN
# Normal Nucleoli                       10
# Bland Chromatin                       10
# Mitoses                               10
# Class                                  4

# %% [markdown]
# ### Check Missing Values

# %%
bc.isnull().sum()
# Out:
# ID                             0
# ClumpThickness                 0
# Cell Size                      0
# Cell Shape                     0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Normal Nucleoli                0
# Bland Chromatin                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %% [markdown]
# ### Check how many `?` there in Bare Nuclei feature (they are also unknown or missing values). Replace them with the top value of the describe function of Bare Nuclei feature.
#
# #### Check include='all' parameter in describe function

# %%
bc['Bare Nuclei'].value_counts()
# Out:
# 1     402
# 10    132
# 2      30
# 5      30
# 3      28
# 8      21
# 4      19
# ?      16
# 9       9
# 7       8
# 6       4
# Name: Bare Nuclei, dtype: int64

# %%
top_value=bc['Bare Nuclei'].describe(include='all').top

# %%
(bc['Bare Nuclei'] ).replace('?', top_value,inplace=True)

# %%
#bc['Bare Nuclei'] = bc['Bare Nuclei'].replace('?',1)

# %%
bc['Bare Nuclei'].value_counts()
# Out:
# 1     418
# 10    132
# 2      30
# 5      30
# 3      28
# 8      21
# 4      19
# 9       9
# 7       8
# 6       4
# Name: Bare Nuclei, dtype: int64

# %%
bc.describe().T
# Out:
#                              count          mean            std      min  \
# ID                           699.0  1.071704e+06  617095.729819  61634.0
# ClumpThickness               699.0  4.417740e+00       2.815741      1.0
# Cell Size                    699.0  3.134478e+00       3.051459      1.0
# Cell Shape                   699.0  3.207439e+00       2.971913      1.0
# Marginal Adhesion            699.0  2.806867e+00       2.855379      1.0
# Single Epithelial Cell Size  699.0  3.216023e+00       2.214300      1.0
# Normal Nucleoli              699.0  3.437768e+00       2.438364      1.0
# Bland Chromatin              699.0  2.866953e+00       3.053634      1.0
# Mitoses                      699.0  1.589413e+00       1.715078      1.0
# Class                        699.0  2.689557e+00       0.951273      2.0
#
#                                   25%        50%        75%         max
# ID                           870688.5  1171710.0  1238298.0  13454352.0
# ClumpThickness                    2.0        4.0        6.0        10.0
# Cell Size                         1.0        1.0        5.0        10.0
# Cell Shape                        1.0        1.0        5.0        10.0
# Marginal Adhesion                 1.0        1.0        4.0        10.0
# Single Epithelial Cell Size       2.0        2.0        4.0        10.0
# Normal Nucleoli                   2.0        3.0        5.0        10.0
# Bland Chromatin                   1.0        1.0        4.0        10.0
# Mitoses                           1.0        1.0        1.0        10.0
# Class                             2.0        2.0        4.0         4.0

# %% [markdown]
# ### Print and plot the distribution of target variable (Class - using Histogram)

# %%
import matplotlib.pyplot as plt
plt.hist(bc['Class'])
# Out:
# (array([458.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0., 241.]),
#  array([2. , 2.2, 2.4, 2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### convert the datatype of Bare Nuclei to `int`

# %%
bc['Bare Nuclei']= bc['Bare Nuclei'].astype('int')

# %%
bc.describe().T
# Out:
#                              count          mean            std      min  \
# ID                           699.0  1.071704e+06  617095.729819  61634.0
# ClumpThickness               699.0  4.417740e+00       2.815741      1.0
# Cell Size                    699.0  3.134478e+00       3.051459      1.0
# Cell Shape                   699.0  3.207439e+00       2.971913      1.0
# Marginal Adhesion            699.0  2.806867e+00       2.855379      1.0
# Single Epithelial Cell Size  699.0  3.216023e+00       2.214300      1.0
# Bare Nuclei                  699.0  3.486409e+00       3.621929      1.0
# Normal Nucleoli              699.0  3.437768e+00       2.438364      1.0
# Bland Chromatin              699.0  2.866953e+00       3.053634      1.0
# Mitoses                      699.0  1.589413e+00       1.715078      1.0
# Class                        699.0  2.689557e+00       0.951273      2.0
#
#                                   25%        50%        75%         max
# ID                           870688.5  1171710.0  1238298.0  13454352.0
# ClumpThickness                    2.0        4.0        6.0        10.0
# Cell Size                         1.0        1.0        5.0        10.0
# Cell Shape                        1.0        1.0        5.0        10.0
# Marginal Adhesion                 1.0        1.0        4.0        10.0
# Single Epithelial Cell Size       2.0        2.0        4.0        10.0
# Bare Nuclei                       1.0        1.0        5.0        10.0
# Normal Nucleoli                   2.0        3.0        5.0        10.0
# Bland Chromatin                   1.0        1.0        4.0        10.0
# Mitoses                           1.0        1.0        1.0        10.0
# Class                             2.0        2.0        4.0         4.0

# %% [markdown]
# ### Standardization of Data (Use Standard Scaler)

# %%
from sklearn import preprocessing
scale = preprocessing.StandardScaler()
scaled_df_arr = scale.fit_transform(bc)
print(scaled_df_arr)
# Out:
# [[-0.11623873  0.20693572 -0.69999505 ... -0.61182504 -0.34391178
#   -0.72539705]
#  [-0.1115035   0.20693572  0.28384518 ... -0.28411186 -0.34391178
#   -0.72539705]
#  [-0.09126525 -0.50386559 -0.69999505 ... -0.61182504 -0.34391178
#   -0.72539705]
#  ...
#  [-0.29657482  0.20693572  2.25152563 ...  2.33759359  0.23956962
#    1.37855538]
#  [-0.28254589 -0.14846494  1.59563215 ...  1.02674087 -0.34391178
#    1.37855538]
#  [-0.28254589 -0.14846494  1.59563215 ...  0.37131451 -0.34391178
#    1.37855538]]

# %%
scaled_df  = pd.DataFrame(scaled_df_arr, columns=bc.columns)
print(scaled_df.head())
# Out:
#          ID  ClumpThickness  Cell Size  Cell Shape  Marginal Adhesion  \
# 0 -0.116239        0.206936  -0.699995   -0.743299          -0.633247
# 1 -0.111504        0.206936   0.283845    0.266875           0.768621
# 2 -0.091265       -0.503866  -0.699995   -0.743299          -0.633247
# 3 -0.089884        0.562336   1.595632    1.613773          -0.633247
# 4 -0.088674       -0.148465  -0.699995   -0.743299           0.067687
#
#    Single Epithelial Cell Size  Bare Nuclei  Normal Nucleoli  Bland Chromatin  \
# 0                    -0.549561    -0.686979        -0.179662        -0.611825
# 1                     1.710106     1.799664        -0.179662        -0.284112
# 2                    -0.549561    -0.410685        -0.179662        -0.611825
# 3                    -0.097628     0.141902        -0.179662         1.354454
# 4                    -0.549561    -0.686979        -0.179662        -0.611825
#
#     Mitoses     Class
# 0 -0.343912 -0.725397
# 1 -0.343912 -0.725397
# 2 -0.343912 -0.725397
# 3 -0.343912 -0.725397
# 4 -0.343912 -0.725397

# %% [markdown]
# ### Plot Scatter Matrix to understand the distribution of variables and check if any variables are collinear and drop one of them. (Use pd.scatter matrix())

# %%
pd.scatter_matrix(bc, alpha=0.2, figsize=(10, 10))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e4294e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e3a4390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e3cb6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e4cd9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e4f8cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e4f8cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e553320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e57e5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e5a4908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e5cec18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e5f8f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e62a278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e654588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e67e898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e6a5ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e6d0eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e705208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e72d518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e757828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e77fb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e7a9e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e7db198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e8044a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e82e7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e858ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e882dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e8b5128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e8dd438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e906748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e930a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e95ad68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e98c0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e9b63c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e9de6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ea079e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ea31cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ea67048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ea8e358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eab8668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eae1978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eb0cc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eb34f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eb682e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eb925f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ebbb908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ebe3c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec0df28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec41278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec69588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec92898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ecbbba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ece9eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ed1a208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ed45518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ed6f828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ed99b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1edc3e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1edf7198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ee224a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ee4c7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ee76ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eea0dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eed2128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eefd438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ef27748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ef51a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ef7cd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1efb00b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1efd93c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f0046d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f02c9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f058cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f08b048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f0b5358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f0de668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f109978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e2c1320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1cd76240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f1853c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f1aaa58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f1dd128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f2057b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f22ce48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f25e518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f288ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f2ba278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f2e1908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f30bf98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f33b668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f361cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f3963c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f3bea58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f3ef128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f4187b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f441e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f471518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f499ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f4cb278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f4f3908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f51cf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f54d668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f577cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f5aa3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f5d0a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f603128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f62a7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f653e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f685518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f6adba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f6e1278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1f708908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f72ff98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f762668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f78bcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f7b93c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f7e4a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f816128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f83c7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f865e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f899518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f8beba8>]],
#       dtype=object)

# %%
import seaborn as sns
sns.pairplot(scaled_df)

# %%
scaled_df.corr()
# Out:
#                                    ID  ClumpThickness  Cell Size  Cell Shape  \
# ID                           1.000000       -0.055308  -0.041603   -0.041576
# ClumpThickness              -0.055308        1.000000   0.644913    0.654589
# Cell Size                   -0.041603        0.644913   1.000000    0.906882
# Cell Shape                  -0.041576        0.654589   0.906882    1.000000
# Marginal Adhesion           -0.064878        0.486356   0.705582    0.683079
# Single Epithelial Cell Size -0.045528        0.521816   0.751799    0.719668
# Bare Nuclei                 -0.092533        0.590008   0.686673    0.707474
# Normal Nucleoli             -0.060051        0.558428   0.755721    0.735948
# Bland Chromatin             -0.052072        0.535835   0.722865    0.719446
# Mitoses                     -0.034901        0.350034   0.458693    0.438911
# Class                       -0.080226        0.716001   0.817904    0.818934
#
#                              Marginal Adhesion  Single Epithelial Cell Size  \
# ID                                   -0.064878                    -0.045528
# ClumpThickness                        0.486356                     0.521816
# Cell Size                             0.705582                     0.751799
# Cell Shape                            0.683079                     0.719668
# Marginal Adhesion                     1.000000                     0.599599
# Single Epithelial Cell Size           0.599599                     1.000000
# Bare Nuclei                           0.666971                     0.583701
# Normal Nucleoli                       0.666715                     0.616102
# Bland Chromatin                       0.603352                     0.628881
# Mitoses                               0.417633                     0.479101
# Class                                 0.696800                     0.682785
#
#                              Bare Nuclei  Normal Nucleoli  Bland Chromatin  \
# ID                             -0.092533        -0.060051        -0.052072
# ClumpThickness                  0.590008         0.558428         0.535835
# Cell Size                       0.686673         0.755721         0.722865
# Cell Shape                      0.707474         0.735948         0.719446
# Marginal Adhesion               0.666971         0.666715         0.603352
# Single Epithelial Cell Size     0.583701         0.616102         0.628881
# Bare Nuclei                     1.000000         0.674215         0.574778
# Normal Nucleoli                 0.674215         1.000000         0.665878
# Bland Chromatin                 0.574778         0.665878         1.000000
# Mitoses                         0.342397         0.344169         0.428336
# Class                           0.818968         0.756616         0.712244
#
#                               Mitoses     Class
# ID                          -0.034901 -0.080226
# ClumpThickness               0.350034  0.716001
# Cell Size                    0.458693  0.817904
# Cell Shape                   0.438911  0.818934
# Marginal Adhesion            0.417633  0.696800
# Single Epithelial Cell Size  0.479101  0.682785
# Bare Nuclei                  0.342397  0.818968
# Normal Nucleoli              0.344169  0.756616
# Bland Chromatin              0.428336  0.712244
# Mitoses                      1.000000  0.423170
# Class                        0.423170  1.000000

# %%
# Cell Size and Cell Shape are collinear, so have to drop one of these. Let us drop Cell Shape
scaled_df = scaled_df.drop('Cell Shape',axis=1)

# %%
print(scaled_df.head())
# Out:
#          ID  ClumpThickness  Cell Size  Marginal Adhesion  \
# 0 -0.116239        0.206936  -0.699995          -0.633247
# 1 -0.111504        0.206936   0.283845           0.768621
# 2 -0.091265       -0.503866  -0.699995          -0.633247
# 3 -0.089884        0.562336   1.595632          -0.633247
# 4 -0.088674       -0.148465  -0.699995           0.067687
#
#    Single Epithelial Cell Size  Bare Nuclei  Normal Nucleoli  Bland Chromatin  \
# 0                    -0.549561    -0.686979        -0.179662        -0.611825
# 1                     1.710106     1.799664        -0.179662        -0.284112
# 2                    -0.549561    -0.410685        -0.179662        -0.611825
# 3                    -0.097628     0.141902        -0.179662         1.354454
# 4                    -0.549561    -0.686979        -0.179662        -0.611825
#
#     Mitoses     Class
# 0 -0.343912 -0.725397
# 1 -0.343912 -0.725397
# 2 -0.343912 -0.725397
# 3 -0.343912 -0.725397
# 4 -0.343912 -0.725397

# %%
scaled_df = scaled_df.drop('ID',axis=1)

# %% [markdown]
# ### Divide the dataset into feature set and target set

# %%
# splitting data into training and test set for independent attributes
from sklearn.model_selection import train_test_split
#X = scaled_df[: , :-1]
#Y = scaled_df[: , -1]
Y = scaled_df['Class']
X= scaled_df.drop('Class', axis=1)

# %%
label_ec = preprocessing.LabelEncoder()
y_encoder = label_ec.fit_transform(Y)

# %% [markdown]
# ### Divide the Training and Test sets in 70:30

# %%
train_set, test_set, train_labels, test_labels = train_test_split(X, y_encoder, test_size=0.30, random_state=0)

# %% [markdown]
# ### Model 1 : Implement a default Decision Tree model with no attributes

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier(criterion = 'entropy' ,random_state=0)
dt_model.fit(train_set, train_labels)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %% [markdown]
# ### Check the feature importances of the Decision Tree model

# %%
dt_model.feature_importances_
# Out:
# array([0.05325326, 0.72335547, 0.01674339, 0.01593082, 0.14164768,
#        0.01366531, 0.03540407, 0.        ])

# %% [markdown]
# ### Check the training & test accuracy of model 1

# %%
from sklearn import metrics
y_pred=dt_model.predict(test_set)   # performance on test data
acc=metrics.accuracy_score(test_labels,y_pred)
print(acc)
# Out:
# 0.9380952380952381

# %% [markdown]
# ### Model 2: Implement a decision tree with depth of the tree = 10 and leaf nodes = 5

# %%
dt_model2 = DecisionTreeClassifier(criterion = 'entropy',max_depth=10, max_leaf_nodes=5 ,random_state=0)
dt_model2.fit(train_set, train_labels)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=5, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=0, splitter='best')

# %% [markdown]
# ### Check the training & test accuracy of model 2

# %%
model2_y_pred=dt_model2.predict(test_set)   # performance on test data
model2_acc=metrics.accuracy_score(test_labels,y_pred)
print(model2_acc)
# Out:
# 0.9380952380952381

# %% [markdown]
# ### Print the confusion matrix of model 1 and model 2

# %%
cm1=metrics.confusion_matrix(test_labels,y_pred)
cm2=metrics.confusion_matrix(test_labels,model2_y_pred)

# %%
print(cm1)
# Out:
# [[127   8]
#  [  5  70]]

# %%
print(cm2)
# Out:
# [[126   9]
#  [  2  73]]
