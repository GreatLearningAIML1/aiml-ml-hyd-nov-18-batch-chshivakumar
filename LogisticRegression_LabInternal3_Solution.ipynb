# %% [markdown]
# # Supervised Learning - Building a Student Performace Prediction System

# %% [markdown]
# # Classification vs. Regression
# The aim of this project is to predict how likely a student is to pass. Which type of supervised learning problem is this, classification or regression? Why?
# Answer:
# This project is a classification supervised learning problem because the variable to predict, i.e. if a student graduates or fails to graduate, is categorical. On this case this a dichotomous categorical variable where the only two possible values are "pass" or "fail".

# %% [markdown]
# ### Overview:
#
# 1.Read the problem statement.
#
# 2.Get the dataset.
#
# 3.Explore the dataset.
#
# 4.Pre-processing of dataset.
#
# 5.Transform the dataset for building machine learning model.
#
# 6.Split data into train, test set.
#
# 7.Build Model.
#
# 8.Apply the model.
#
# 9.Evaluate the model.
#
# 10.Provide insights.

# %% [markdown]
# ## Problem Statement
#
# Using Logistic Regression **predict the performance of student**. The classification goal is to predict whether the student will pass or fail.
#
# ## Dataset
#
# This data approach student achievement in secondary education of two Portuguese schools. The data attributes include student grades, demographic, social and school related features) and it was collected by using school reports and questionnaires. Two datasets are provided regarding the performance in Mathematics.
#
# **Source:** https://archive.ics.uci.edu/ml/datasets/Student+Performance

# %% [markdown]
# # Question 1 - Exploring the Data (0.5 points)
# *Read the dataset file using pandas. Take care about the delimiter.*
#
# #### Answer:

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
students_df = pd.read_csv('students-data.csv', ';')
students_df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# # Question 2 - drop missing values (0.5 points)
# *Set the index name of the dataframe to **"number"**. Check sample of data to drop if any missing values are there.*
# *Use .dropna() function to drop the NAs*
#
# #### Answer:

# %%
students_df.index.name='number'

# %%
students_df.dropna()
# Out:
#        school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# number
# 0          GP   F   18       U     GT3       A     4     4   at_home
# 1          GP   F   17       U     GT3       T     1     1   at_home
# 2          GP   F   15       U     LE3       T     1     1   at_home
# 3          GP   F   15       U     GT3       T     4     2    health
# 4          GP   F   16       U     GT3       T     3     3     other
# 5          GP   M   16       U     LE3       T     4     3  services
# 6          GP   M   16       U     LE3       T     2     2     other
# 7          GP   F   17       U     GT3       A     4     4     other
# 8          GP   M   15       U     LE3       A     3     2  services
# 9          GP   M   15       U     GT3       T     3     4     other
# 10         GP   F   15       U     GT3       T     4     4   teacher
# 11         GP   F   15       U     GT3       T     2     1  services
# ...

# %%
# No missing values found

# %% [markdown]
# # Transform Data
#
# ## Question 3 (0.5 points)
#
# *Print all the attribute names which are not numerical.*
#
# **Hint:** check **select_dtypes()** and its **include** and **exclude** parameters.**
#
# #### Answer:

# %%
students_df.select_dtypes(exclude=['int64']).columns
#students_df.select_dtypes(exclude=np.number)
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')

# %% [markdown]
# # Question 4 - Drop variables with less variance (0.5 points)
#
# *Find the variance of each numerical independent variable and drop whose variance is less than 1. Use .var function to check the variance*

# %%
less=(students_df.var()<1)
col=[i for i in less.keys() if less.get(i)==True]
col
# Out:
# ['traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'Dalc']

# %%
# students_df.var()
# columns_remove = []
# for column in students_df.select_dtypes(exclude=['int64']).columns:
#     if students_df[column].var()<1:
#         columns_remove.append(column)
        
# print(columns_remove)

# %%
#list=['traveltime','studytime','failures','famrel','freetime','Dalc']
# students_df.drop[col,axis=1,inplace=True]
students_df.drop(columns=col, inplace=True)

# %%
students_df.head()
# Out:
#        school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# number
# 0          GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1          GP   F   17       U     GT3       T     1     1  at_home     other
# 2          GP   F   15       U     LE3       T     1     1  at_home     other
# 3          GP   F   15       U     GT3       T     4     2   health  services
# 4          GP   F   16       U     GT3       T     3     3    other     other
#
#        ... higher internet romantic goout Walc health absences  G1  G2  G3
# number ...
# 0      ...    yes       no       no     4    1      3        6   5   6   6
# 1      ...    yes      yes       no     3    1      3        4   5   5   6
# 2      ...    yes      yes       no     2    3      3       10   7   8  10
# 3      ...    yes      yes      yes     2    1      5        2  15  14  15
# 4      ...    yes       no       no     2    2      5        4   6  10  10
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Variables with less variance are almost same for all the records. Hence, they do not contribute much for classification.

# %% [markdown]
# # Question 6 - Encode all categorical variables to numerical (0.5 points)
#
# Take the list of categorical attributes(from the above result) and convert them into neumerical variables. After that, print the head of dataframe and check the values.
#
# **Hint:** check **sklearn LabelEncoder()**
#
# #### Answer:

# %%
cat_labels=students_df.select_dtypes(exclude=np.number).columns
cat_labels
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')

# %%
from sklearn.preprocessing import  LabelEncoder
labelEncoder=LabelEncoder()
students_df[cat_labels]=students_df[cat_labels].apply(labelEncoder.fit_transform)
students_df.head()
# Out:
#         school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# number
# 0            0    0   18        1        0        0     4     4     0     4
# 1            0    0   17        1        0        1     1     1     0     2
# 2            0    0   15        1        1        1     1     1     0     2
# 3            0    0   15        1        0        1     4     2     1     3
# 4            0    0   16        1        0        1     3     3     2     2
#
#        ...  higher  internet  romantic  goout  Walc  health  absences  G1  G2  \
# number ...
# 0      ...       1         0         0      4     1       3         6   5   6
# 1      ...       1         1         0      3     1       3         4   5   5
# 2      ...       1         1         0      2     3       3        10   7   8
# 3      ...       1         1         1      2     1       5         2  15  14
# 4      ...       1         0         0      2     2       5         4   6  10
#
#         G3
# ...

# %% [markdown]
# # Question 7 - Convert the continuous values of grades into classes (1 point)
#
# *Consider the values in G1, G2 and G3 with >= 10 as pass(1) and < 10 as fail(0) and encode them into binary values. Print head of dataframe to check the values.*
#
# #### Answer:

# %%
# students_df['G1']=students_df['G1'].apply(lambda x: x>=10)

# %%
# students_df['G2']=students_df['G2'].apply(lambda x: x>=10)

# %%
# students_df['G3']=students_df['G3'].apply(lambda x: x>=10)

# %%
row_count=students_df.shape[0]-1
print(row_count)
# Out:
# 394

# %%
# grades=['G1','G2','G3']
# for g in grades:
#     for row in students_df[g]
#     if row >= 10
#         row = 1
#     else
#         row = 0
for index in range(0, row_count):
    if students_df.loc[index]['G1']>=10:
        students_df.loc[index]['G1']=1
    else:
        students_df.loc[index]['G1']=0
            
    if students_df.loc[index]['G2']>=10:
        students_df.loc[index]['G2']=1
    else:
        students_df.loc[index]['G2']=0
            
    if students_df.loc[index]['G3']>=10:
        students_df.loc[index]['G3']=1
    else:
        students_df.loc[index]['G3']=0

# %%
students_df.head()
# Out:
#         school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# number
# 0            0    0   18        1        0        0     4     4     0     4
# 1            0    0   17        1        0        1     1     1     0     2
# 2            0    0   15        1        1        1     1     1     0     2
# 3            0    0   15        1        0        1     4     2     1     3
# 4            0    0   16        1        0        1     3     3     2     2
#
#        ...  higher  internet  romantic  goout  Walc  health  absences  G1  G2  \
# number ...
# 0      ...       1         0         0      4     1       3         6   0   0
# 1      ...       1         1         0      3     1       3         4   0   0
# 2      ...       1         1         0      2     3       3        10   0   0
# 3      ...       1         1         1      2     1       5         2   1   1
# 4      ...       1         0         0      2     2       5         4   0   1
#
#         G3
# ...

# %%
students_df[['G1','G2','G3']]=students_df[['G1','G2','G3']].apply(labelEncoder.fit_transform)
students_df.corr()
# Out:
#               school       sex       age   address   famsize   Pstatus  \
# school      1.000000 -0.012286  0.377610 -0.279797  0.064866  0.045923
# sex        -0.012286  1.000000 -0.028606 -0.028504  0.089862  0.023443
# age         0.377610 -0.028606  1.000000 -0.146722  0.037847  0.029598
# address    -0.279797 -0.028504 -0.146722  1.000000  0.072472 -0.042572
# famsize     0.064866  0.089862  0.037847  0.072472  1.000000 -0.149612
# Pstatus     0.045923  0.023443  0.029598 -0.042572 -0.149612  1.000000
# Medu       -0.133333  0.078228 -0.163658  0.138804 -0.043068 -0.123565
# Fedu       -0.079807  0.034878 -0.163438  0.072178 -0.058879 -0.088730
# Mjob       -0.056670  0.191421 -0.069104  0.108818  0.071386 -0.054476
# Fjob        0.018974  0.084957 -0.035191 -0.001911 -0.084448  0.033892
# reason     -0.090010 -0.095867 -0.015337 -0.047891 -0.019212 -0.003553
# guardian    0.011109 -0.071343  0.290485 -0.044512 -0.002718 -0.108715
# ...

# %% [markdown]
# # Question 8 (0.5 points)
#
# *Consider G3 is the target attribute and remaining all attributes as features to predict G3. Now, separate feature and target attributes into separate dataframes with X and y variable names.*

# %%
Train_set=students_df.drop(columns='G3')

Test_set=students_df.pop('G3')

# %%
size=300/students_df.count()
size
# Out:
# school        0.759494
# sex           0.759494
# age           0.759494
# address       0.759494
# famsize       0.759494
# Pstatus       0.759494
# Medu          0.759494
# Fedu          0.759494
# Mjob          0.759494
# Fjob          0.759494
# reason        0.759494
# guardian      0.759494
# schoolsup     0.759494
# famsup        0.759494
# paid          0.759494
# activities    0.759494
# nursery       0.759494
# higher        0.759494
# internet      0.759494
# romantic      0.759494
# goout         0.759494
# Walc          0.759494
# health        0.759494
# absences      0.759494
# G1            0.759494
# G2            0.759494
# dtype: float64

# %% [markdown]
# # Question 9 - Training and testing data split (0.5 points)

# %% [markdown]
# # *So far, you have converted all categorical features into numeric values. Now, split the data into training and test sets with training size of 300 records. Print the number of train and test records.*
#
# **Hint:** check **train_test_split()** from **sklearn**
#
# #### Answer:

# %%
from sklearn.model_selection import  train_test_split
Xtrain,Xtest,Ytrain,Ytest=train_test_split(Train_set,Test_set,test_size=0.25,random_state=1)

# %%
Xtrain.shape
# Out:
# (296, 26)

# %% [markdown]
# # Question 10 - Model Implementation and Testing the Accuracy (0.5 points)
#
# *Build a **LogisticRegression** classifier using **fit()** functions in sklearn.
# * You need to import both Logistic regression and accuracy score from sklearn*
# #### Answer:

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model.fit(Xtrain,Ytrain)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# # Question 11 - Print the intercept of the Logistic regression model (0.5 points)

# %% [markdown]
# The value of the intercepts are stored in the model itself. You can use .intercept_ function to do the same

# %%
model.intercept_
# Out:
# array([0.49678668])

# %% [markdown]
# # Question 12 - Print the coefficients of the model (0.5 points) and name the coefficient which has the highest impact on the dependent variable (0.5 points)

# %% [markdown]
# Hint: Use .coef_ to get the coefficients and use pd.Dataframe to store the coefficients in a dataframe with column names same as the independent variable dataframe

# %%
model.coef_
# Out:
# array([[ 0.07027723, -0.08926415, -0.16877031,  0.08331242,  0.20341835,
#         -0.38257987,  0.21406968, -0.42584781, -0.11968208,  0.28854839,
#          0.24859935,  0.04443033, -0.45656249, -0.39859617,  0.33442806,
#         -0.23191181, -0.01114604,  1.10129806,  0.12150099, -0.64031283,
#         -0.1827294 ,  0.30202428, -0.03738543, -0.02719112,  1.33225088,
#          3.87723768]])

# %%
pd.DataFrame(model.coef_,columns=students_df.columns)
#G2 has the highest impact
# Out:
#      school       sex      age   address   famsize  Pstatus     Medu  \
# 0  0.070277 -0.089264 -0.16877  0.083312  0.203418 -0.38258  0.21407
#
#        Fedu      Mjob      Fjob    ...      nursery    higher  internet  \
# 0 -0.425848 -0.119682  0.288548    ...    -0.011146  1.101298  0.121501
#
#    romantic     goout      Walc    health  absences        G1        G2
# 0 -0.640313 -0.182729  0.302024 -0.037385 -0.027191  1.332251  3.877238
#
# [1 rows x 26 columns]

# %% [markdown]
# # Question 13 - Predict the dependent variable for both training and test dataset (0.5 points)

# %% [markdown]
# Accuracy score() should help you to print the accuracies

# %%
from sklearn import  metrics
ypred=model.predict(Xtest)
acc=metrics.accuracy_score(Ytest,ypred)
print(acc)
# Out:
# 0.9090909090909091
